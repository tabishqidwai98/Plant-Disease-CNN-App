# %%
import pandas as pd
import numpy as np

# %%
# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
import tensorflow as tf
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [12], line 1
# ----> 1 import tensorflow as tf
#
# File c:\Users\tabis\anaconda3\lib\site-packages\tensorflow\__init__.py:41
#      38 import six as _six
#      39 import sys as _sys
# ---> 41 from tensorflow.python.tools import module_util as _module_util
#      42 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      44 # Make sure code inside the TensorFlow codebase can use tf2.enabled() at import.
#
# File c:\Users\tabis\anaconda3\lib\site-packages\tensorflow\python\__init__.py:49
#      47 from tensorflow.python import distribute
#      48 # from tensorflow.python import keras
# ---> 49 from tensorflow.python.feature_column import feature_column_lib as feature_column
#      50 # from tensorflow.python.layers import layers
#      51 from tensorflow.python.module import module
#
# ...
